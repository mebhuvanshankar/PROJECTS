# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\LoanAmountlPrediction (1).csv")
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No         0.0      Graduate            No
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 593  LP002978  Female      No         0.0      Graduate            No
# 594  LP002979    Male     Yes         3.0      Graduate            No
# 595  LP002983    Male     Yes         1.0      Graduate            No
# 596  LP002984    Male     Yes         2.0      Graduate            No
# 597  LP002990  Female      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married  Dependents Education Self_Employed  \
# 593  LP002978  Female      No         0.0  Graduate            No
# 594  LP002979    Male     Yes         3.0  Graduate            No
# 595  LP002983    Male     Yes         1.0  Graduate            No
# 596  LP002984    Male     Yes         2.0  Graduate            No
# 597  LP002990  Female      No         0.0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 593             2900                0.0        71.0             360.0
# 594             4106                0.0        40.0             180.0
# 595             8072              240.0       253.0             360.0
# 596             7583                0.0       187.0             360.0
# 597             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 593             1.0         Rural           Y
# 594             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (598, 13)

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# Loan_ID              0.000000
# Gender               0.000000
# Married              0.000000
# Dependents           2.006689
# Education            0.000000
# Self_Employed        0.000000
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.511706
# Loan_Amount_Term     2.341137
# Credit_History       8.193980
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            598 non-null    object
#  1   Gender             598 non-null    object
#  2   Married            598 non-null    object
#  3   Dependents         586 non-null    float64
#  4   Education          598 non-null    object
#  5   Self_Employed      598 non-null    object
#  6   ApplicantIncome    598 non-null    int64
#  7   CoapplicantIncome  598 non-null    float64
#  8   LoanAmount         577 non-null    float64
#  9   Loan_Amount_Term   584 non-null    float64
#  10  Credit_History     549 non-null    float64
#  11  Property_Area      598 non-null    object
#  12  Loan_Status        598 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 60.9+ KB

# %%
df = df.drop('Loan_ID',axis = 1)

# %%
df
# Out:
#      Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No         0.0      Graduate            No             5849
# 1      Male     Yes         1.0      Graduate            No             4583
# 2      Male     Yes         0.0      Graduate           Yes             3000
# 3      Male     Yes         0.0  Not Graduate            No             2583
# 4      Male      No         0.0      Graduate            No             6000
# ..      ...     ...         ...           ...           ...              ...
# 593  Female      No         0.0      Graduate            No             2900
# 594    Male     Yes         3.0      Graduate            No             4106
# 595    Male     Yes         1.0      Graduate            No             8072
# 596    Male     Yes         2.0      Graduate            No             7583
# 597  Female      No         0.0      Graduate           Yes             4583
#
# ...

# %%
columns = ['Dependents', 'Gender', 'LoanAmount', 'Loan_Amount_Term']
df = df.dropna(subset = columns)
df.isnull().sum()
# Out:
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       48
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])
# Out:
# C:\Users\Bhuvanshankar K\AppData\Local\Temp\ipykernel_10968\462730932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
# C:\Users\Bhuvanshankar K\AppData\Local\Temp\ipykernel_10968\462730932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Gender'] = df['Gender'].map({'Male':1,'Female':0}).astype('int')
df['Married'] = df['Married'].map({'Yes':1,'No':0}).astype('int')
df['Education'] = df['Education'].map({'Graduate':1,'Not Graduate':0}).astype('int')
df['Self_Employed'] = df['Self_Employed'].map({'Yes':1,'No':0}).astype('int')
df['Property_Area'] = df['Property_Area'].map({'Rural':0,'Semiurban':2,'Urban':1}).astype('int')
df['Loan_Status'] = df['Loan_Status'].map({'Y':1,'N':0}).astype('int')
df.sample(10)
# Out:
# C:\Users\Bhuvanshankar K\AppData\Local\Temp\ipykernel_10968\2619603475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].map({'Male':1,'Female':0}).astype('int')
# C:\Users\Bhuvanshankar K\AppData\Local\Temp\ipykernel_10968\2619603475.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Married'] = df['Married'].map({'Yes':1,'No':0}).astype('int')
# C:\Users\Bhuvanshankar K\AppData\Local\Temp\ipykernel_10968\2619603475.py:3: SettingWithCopyWarning:
# ...

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1         1.0          1              0             4583
# 2         1        1         0.0          1              1             3000
# 3         1        1         0.0          0              0             2583
# 4         1        0         0.0          1              0             6000
# 5         1        1         2.0          1              1             5417
# ..      ...      ...         ...        ...            ...              ...
# 593       0        0         0.0          1              0             2900
# 594       1        1         3.0          1              0             4106
# 595       1        1         1.0          1              0             8072
# 596       1        1         2.0          1              0             7583
# 597       0        0         0.0          1              1             4583
#
# ...

# %%
y
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 593    1
# 594    1
# 595    1
# 596    1
# 597    0
# Name: Loan_Status, Length: 553, dtype: int32

# %%
columns = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
x[columns]=st.fit_transform(x[columns])

# %%
x.sample(5)
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 485       1        1         0.0          1              0        -0.121647
# 172       1        1         2.0          1              0        -0.554530
# 90        1        1         2.0          1              0         0.151003
# 452       1        1         0.0          1              0        -0.391779
# 303       1        1         2.0          0              0         0.388753
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 485           0.393950   -0.416807         -5.033329             1.0
# 172          -0.013194   -0.535889          0.279961             1.0
# 90            1.313805    0.500121         -2.468292             1.0
# 452           0.173934    0.083336          0.279961             1.0
# 303          -0.545638    0.464397          0.279961             1.0
#
#      Property_Area
# 485              1
# 172              0
# 90               2
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

regressor = LogisticRegression()
regressor.fit(x_train,y_train)
y_pred = regressor.predict(x_test)

print(f"{regressor}) accuracy is {accuracy_score(y_test,y_pred)*100}%")

cvscore = cross_val_score(regressor,x,y,cv=5)
print(f"{regressor}) Avg cross val score is {np.mean(cvscore)*100}%")
# Out:
# LogisticRegression()) accuracy is 81.98198198198197%
# LogisticRegression()) Avg cross val score is 80.47829647829647%

# %%
from sklearn.ensemble import RandomForestClassifier

regressor = RandomForestClassifier()
regressor.fit(x_train,y_train)
y_pred = regressor.predict(x_test)

print(f"{regressor}) accuracy is {accuracy_score(y_test,y_pred)*100}%")

cvscore = cross_val_score(regressor,x,y,cv=5)
print(f"{regressor}) Avg cross val score is {np.mean(cvscore)*100}%")
# Out:
# RandomForestClassifier()) accuracy is 79.27927927927928%
# RandomForestClassifier()) Avg cross val score is 78.66502866502867%

# %%
from sklearn.tree import DecisionTreeClassifier

regressor = DecisionTreeClassifier()
regressor.fit(x_train,y_train)
y_pred = regressor.predict(x_test)

print(f"{regressor}) accuracy is {accuracy_score(y_test,y_pred)*100}%")

cvscore = cross_val_score(regressor,x,y,cv=5)
print(f"{regressor}) Avg cross val score is {np.mean(cvscore)*100}%")
# Out:
# DecisionTreeClassifier()) accuracy is 72.07207207207207%
# DecisionTreeClassifier()) Avg cross val score is 71.07125307125305%
